# %% [markdown]
# # WEATHER PREDICTION

# %% [markdown]
# ## IMPORTING REQUIRED PACKAGES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## LOADING DATA FROM DATA SOURCE

# %%
df = pd.read_csv("pune.csv")
df
# Out:
#                  date_time  maxtempC  mintempC  sunHour  uvIndex  \
# 0      2017-01-01 01:00:00      31.0      17.0     11.0      6.0
# 1      2017-01-01 02:00:00      31.0      17.0     11.0      6.0
# 2      2017-01-01 03:00:00      31.0      17.0     11.0      6.0
# 3      2017-01-01 04:00:00      31.0      17.0     11.0      6.0
# 4      2017-01-01 05:00:00      31.0      17.0      NaN      6.0
# ...                    ...       ...       ...      ...      ...
# 45498  2022-03-11 19:00:00      35.0      23.0     11.8      7.0
# 45499  2022-03-11 20:00:00      35.0      23.0     11.8      7.0
# 45500  2022-03-11 21:00:00      35.0      23.0     11.8      7.0
# 45501  2022-03-11 22:00:00      35.0      23.0     11.8      7.0
# 45502  2022-03-11 23:00:00      35.0      23.0     11.8      7.0
#
#        moon_illumination  moonrise   moonset   sunrise    sunset  ...  \
# 0                   20.0  09:15 AM  08:58 PM  07:07 AM  06:09 PM  ...
# 1                   20.0  09:15 AM  08:58 PM  07:07 AM  06:09 PM  ...
# 2                   20.0  09:15 AM  08:58 PM  07:07 AM  06:09 PM  ...
# 3                   20.0  09:15 AM  08:58 PM  07:07 AM  06:09 PM  ...
# 4                   20.0  09:15 AM  08:58 PM  07:07 AM  06:09 PM  ...
# ...                  ...       ...       ...       ...       ...  ...
# 45498               56.0  12:40 PM  01:33 AM  06:46 AM  06:43 PM  ...
# 45499               56.0  12:40 PM  01:33 AM  06:46 AM  06:43 PM  ...
# 45500               56.0  12:40 PM  01:33 AM  06:46 AM  06:43 PM  ...
# 45501               56.0  12:40 PM  01:33 AM  06:46 AM  06:43 PM  ...
# 45502               56.0  12:40 PM  01:33 AM  06:46 AM  06:43 PM  ...
#
#        WindChillC  WindGustKmph  cloudcover  humidity  precipMM  pressure  \
# 0            18.0           5.0           1        63       0.0    1014.0
# 1            18.0           5.0           0        63       0.0    1014.0
# 2            17.0           6.0           0        64       0.0    1014.0
# 3            19.0           7.0           1        57       0.0    1014.0
# 4            19.0           8.0           1        51       0.0    1015.0
# ...           ...           ...         ...       ...       ...       ...
# 45498        30.0          10.0           6        28       0.0    1009.0
# 45499        29.0          14.0           7        29       0.0    1010.0
# 45500        27.0          12.0           9        30       0.0    1012.0
# 45501        26.0          14.0           8        31       0.0    1011.0
# 45502        25.0          15.0           7        32       0.0    1011.0
#
#        tempC  visibility  winddirDegree  windspeedKmph
# 0         18          10             82              2
# 1         18          10             94              3
# 2         17          10            105              3
# 3         19          10            110              4
# 4         19          10            115              5
# ...      ...         ...            ...            ...
# 45498     30          10            235              7
# 45499     29          10            289              9
# 45500     27          10            343             12
# 45501     26          10            234             11
# 45502     25          10            125             10
#
# [45503 rows x 23 columns]

# %% [markdown]
# ## DATA VISUALIZATION

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,3,figsize=(10,8))
sns.histplot(data=df,x="maxtempC",kde=True,ax=axs[0,0],color='red')
sns.histplot(data=df,x="mintempC",kde=True,ax=axs[0,1],color='green')
sns.histplot(data=df,x="pressure",kde=True,ax=axs[0,2],color='blue')
sns.histplot(data=df,x="humidity",kde=True,ax=axs[1,0],color='orange')
sns.histplot(data=df,x="HeatIndexC",kde=True,ax=axs[1,1],color='black')
sns.histplot(data=df,x="uvIndex",kde=True,ax=axs[1,2],color='yellow')

plt.savefig('Histogram showing the distribution of numerical variables in the dataset')

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### - General Information

# %%
df.shape
# Out:
# (45503, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45503 entries, 0 to 45502
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          45501 non-null  object
#  1   maxtempC           44633 non-null  float64
#  2   mintempC           45478 non-null  float64
#  3   sunHour            45351 non-null  float64
#  4   uvIndex            45450 non-null  float64
#  5   moon_illumination  45502 non-null  float64
#  6   moonrise           45503 non-null  object
#  7   moonset            45503 non-null  object
#  8   sunrise            45503 non-null  object
#  9   sunset             45503 non-null  object
#  10  DewPointC          45500 non-null  float64
#  11  FeelsLikeC         45503 non-null  int64
#  12  HeatIndexC         45503 non-null  int64
#  13  WindChillC         45478 non-null  float64
#  14  WindGustKmph       45494 non-null  float64
#  15  cloudcover         45503 non-null  int64
#  16  humidity           45503 non-null  int64
#  17  precipMM           45487 non-null  float64
#  18  pressure           45501 non-null  float64
#  19  tempC              45503 non-null  int64
#  20  visibility         45503 non-null  int64
#  21  winddirDegree      45503 non-null  int64
#  22  windspeedKmph      45503 non-null  int64
# dtypes: float64(10), int64(8), object(5)
# memory usage: 8.0+ MB

# %% [markdown]
# ### - Statistical Information

# %%
df.describe()
# Out:
#            maxtempC      mintempC       sunHour       uvIndex  \
# count  44633.000000  45478.000000  45351.000000  45450.000000
# mean      30.831201     21.249307     11.087453      6.266249
# std        4.242974      2.667357      1.002336      0.924189
# min       22.000000     11.000000      8.300000      4.000000
# 25%       28.000000     20.000000     10.500000      6.000000
# 50%       30.000000     22.000000     11.000000      6.000000
# 75%       34.000000     23.000000     11.800000      7.000000
# max       42.000000     28.000000     13.500000      8.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       45502.000000  45500.000000  45503.000000  45503.000000
# mean           46.087557  43464.701736     26.322221     26.491462
# std            31.231273  13136.110646      4.384641      4.242005
# min             0.000000  20714.000000     10.000000     11.000000
# 25%            19.000000  32088.750000     25.000000     25.000000
# 50%            46.000000  43463.500000     26.000000     26.000000
# 75%            73.000000  54841.250000     29.000000     29.000000
# max           100.000000  66216.000000     44.000000     44.000000
#
#          WindChillC  WindGustKmph    cloudcover      humidity      precipMM  \
# count  45478.000000  45494.000000  45503.000000  45503.000000  45487.000000
# mean      25.437706     18.101552     31.633013     56.551348      0.246156
# std        4.562040      8.647081     33.945653     24.535400      0.883922
# min       10.000000      1.000000      0.000000      4.000000      0.000000
# 25%       23.000000     12.000000      2.000000     36.000000      0.000000
# 50%       25.000000     16.000000     13.000000     57.000000      0.000000
# 75%       28.000000     23.000000     66.000000     80.000000      0.100000
# max       42.000000     76.000000    100.000000     98.000000     25.700000
#
#            pressure         tempC    visibility  winddirDegree  windspeedKmph
# count  45501.000000  45503.000000  45503.000000   45503.000000   45503.000000
# mean    1009.847981     25.438543      9.629739     208.436389      10.298332
# std        3.594591      4.562331      1.131830      87.580946       5.138205
# min      997.000000     11.000000      2.000000       0.000000       0.000000
# 25%     1007.000000     23.000000     10.000000     113.000000       6.000000
# 50%     1010.000000     25.000000     10.000000     253.000000       9.000000
# 75%     1013.000000     28.000000     10.000000     273.000000      14.000000
# max     1020.000000     42.000000     10.000000     360.000000      40.000000

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ### - Deleting Unnecessary Attributes

# %%
df.drop(['date_time', 'moonrise', 'moonset', 'sunrise', 'sunset'], axis = 1, inplace = True)

# %% [markdown]
# ### - Finding The Missing Data (NaN Values)

# %%
df.isna().sum()
# Out:
# maxtempC             870
# mintempC              25
# sunHour              152
# uvIndex               53
# moon_illumination      1
# DewPointC              3
# FeelsLikeC             0
# HeatIndexC             0
# WindChillC            25
# WindGustKmph           9
# cloudcover             0
# humidity               0
# precipMM              16
# pressure               2
# tempC                  0
# visibility             0
# winddirDegree          0
# windspeedKmph          0
# dtype: int64

# %% [markdown]
# ### - Filling The Missing Data

# %%
filled_df = df.fillna(df.mean())

# %% [markdown]
# ### - Finding correlation

# %%
filled_df.corr()
# Out:
#                    maxtempC  mintempC   sunHour   uvIndex  moon_illumination  \
# maxtempC           1.000000  0.429022  0.723808  0.866906           0.004190
# mintempC           0.429022  1.000000  0.255026  0.409274          -0.038052
# sunHour            0.723808  0.255026  1.000000  0.712544           0.036009
# uvIndex            0.866906  0.409274  0.712544  1.000000           0.008191
# moon_illumination  0.004190 -0.038052  0.036009  0.008191           1.000000
# DewPointC         -0.189332 -0.108689 -0.161966 -0.146142          -0.008397
# FeelsLikeC         0.471923  0.609633  0.333115  0.438964          -0.011597
# HeatIndexC         0.467557  0.613682  0.322980  0.434485          -0.013183
# WindChillC         0.557295  0.484167  0.394908  0.510319          -0.010274
# WindGustKmph      -0.224228  0.231957 -0.168150 -0.257769          -0.017094
# cloudcover        -0.610054  0.240087 -0.614019 -0.598102          -0.039312
# humidity          -0.644456  0.112734 -0.521720 -0.590427          -0.011973
# precipMM          -0.283327  0.096222 -0.286636 -0.277881          -0.042880
# pressure           0.134557 -0.571069  0.154237  0.157518           0.030758
# tempC              0.557388  0.484394  0.394818  0.510369          -0.010730
# visibility         0.250458 -0.112651  0.271440  0.234730           0.033868
# winddirDegree      0.114216  0.377126  0.064737  0.039016          -0.016528
# windspeedKmph     -0.199521  0.266138 -0.118751 -0.225502          -0.008115
#
#                    DewPointC  FeelsLikeC  HeatIndexC  WindChillC  \
# maxtempC           -0.189332    0.471923    0.467557    0.557295
# mintempC           -0.108689    0.609633    0.613682    0.484167
# sunHour            -0.161966    0.333115    0.322980    0.394908
# uvIndex            -0.146142    0.438964    0.434485    0.510319
# moon_illumination  -0.008397   -0.011597   -0.013183   -0.010274
# DewPointC           1.000000   -0.092163   -0.087752   -0.091453
# FeelsLikeC         -0.092163    1.000000    0.989465    0.948120
# HeatIndexC         -0.087752    0.989465    1.000000    0.945307
# WindChillC         -0.091453    0.948120    0.945307    1.000000
# WindGustKmph       -0.032218    0.309594    0.304092    0.230955
# cloudcover          0.107163    0.008526    0.014495   -0.169842
# humidity            0.089646   -0.349516   -0.338605   -0.550566
# precipMM           -0.000224    0.012155    0.012116   -0.062194
# pressure           -0.037621   -0.396118   -0.398888   -0.238400
# tempC              -0.091374    0.948453    0.945683    0.999523
# visibility          0.025850    0.010455    0.003516    0.086908
# winddirDegree      -0.032779    0.176468    0.176275    0.087081
# windspeedKmph      -0.019788    0.318855    0.312744    0.229318
#
#                    WindGustKmph  cloudcover  humidity  precipMM  pressure  \
# maxtempC              -0.224228   -0.610054 -0.644456 -0.283327  0.134557
# mintempC               0.231957    0.240087  0.112734  0.096222 -0.571069
# sunHour               -0.168150   -0.614019 -0.521720 -0.286636  0.154237
# uvIndex               -0.257769   -0.598102 -0.590427 -0.277881  0.157518
# moon_illumination     -0.017094   -0.039312 -0.011973 -0.042880  0.030758
# DewPointC             -0.032218    0.107163  0.089646 -0.000224 -0.037621
# FeelsLikeC             0.309594    0.008526 -0.349516  0.012155 -0.396118
# HeatIndexC             0.304092    0.014495 -0.338605  0.012116 -0.398888
# WindChillC             0.230955   -0.169842 -0.550566 -0.062194 -0.238400
# WindGustKmph           1.000000    0.468357  0.214432  0.319201 -0.531688
# cloudcover             0.468357    1.000000  0.720188  0.404386 -0.613805
# humidity               0.214432    0.720188  1.000000  0.291691 -0.450990
# precipMM               0.319201    0.404386  0.291691  1.000000 -0.348235
# pressure              -0.531688   -0.613805 -0.450990 -0.348235  1.000000
# tempC                  0.231194   -0.169764 -0.550998 -0.062186 -0.238533
# visibility            -0.144317   -0.411698 -0.346110 -0.366214  0.303554
# winddirDegree          0.245818    0.236747  0.254057  0.116550 -0.464104
# windspeedKmph          0.917856    0.446894  0.219957  0.246695 -0.509200
#
#                       tempC  visibility  winddirDegree  windspeedKmph
# maxtempC           0.557388    0.250458       0.114216      -0.199521
# mintempC           0.484394   -0.112651       0.377126       0.266138
# sunHour            0.394818    0.271440       0.064737      -0.118751
# uvIndex            0.510369    0.234730       0.039016      -0.225502
# moon_illumination -0.010730    0.033868      -0.016528      -0.008115
# DewPointC         -0.091374    0.025850      -0.032779      -0.019788
# FeelsLikeC         0.948453    0.010455       0.176468       0.318855
# HeatIndexC         0.945683    0.003516       0.176275       0.312744
# WindChillC         0.999523    0.086908       0.087081       0.229318
# WindGustKmph       0.231194   -0.144317       0.245818       0.917856
# cloudcover        -0.169764   -0.411698       0.236747       0.446894
# humidity          -0.550998   -0.346110       0.254057       0.219957
# precipMM          -0.062186   -0.366214       0.116550       0.246695
# pressure          -0.238533    0.303554      -0.464104      -0.509200
# tempC              1.000000    0.086855       0.087128       0.229594
# visibility         0.086855    1.000000      -0.103275      -0.093858
# winddirDegree      0.087128   -0.103275       1.000000       0.280766
# windspeedKmph      0.229594   -0.093858       0.280766       1.000000

# %%
sns.heatmap(filled_df.corr())
# Out:
# <Axes: >

# %%
filled_df.isna().sum()
# Out:
# maxtempC             0
# mintempC             0
# sunHour              0
# uvIndex              0
# moon_illumination    0
# DewPointC            0
# FeelsLikeC           0
# HeatIndexC           0
# WindChillC           0
# WindGustKmph         0
# cloudcover           0
# humidity             0
# precipMM             0
# pressure             0
# tempC                0
# visibility           0
# winddirDegree        0
# windspeedKmph        0
# dtype: int64

# %% [markdown]
# ### Splitting Data into X and Y

# %%
X= filled_df.drop(['tempC','moon_illumination','DewPointC','cloudcover','precipMM','visibility','winddirDegree','sunHour','WindChillC','WindGustKmph','windspeedKmph','FeelsLikeC'],axis=1)
Y= filled_df['tempC']

# %% [markdown]
# ### Splitting X and Y into train and test datasets

# %%
from sklearn.model_selection import train_test_split

# split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, random_state=12345)

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ### - Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
import pickle
model = LinearRegression()
model.fit(x_train, y_train)
def save_model(model, name):
    with open(name, 'wb') as file:
        pickle.dump(model, file)

save_model(model,'lg.pkl')

# %% [markdown]
# ## MODEL EVALUATION

# %% [markdown]
# ### Evaluating y_true and y_pred

# %%
y_true = y_test
y_pred = model.predict(x_test)

# %% [markdown]
# ### - Mean Absolute Error (MAE)

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.7352070758424476

# %% [markdown]
# ### - Mean Squared Error (MSE)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.9249420456695954

# %% [markdown]
# ### - R2 Score

# %%
from sklearn.metrics import r2_score
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.954882281914995

# %% [markdown]
# ## PREDICTION

# %%
input_data = np.array([[31,17,11,18,63,1014]]) 
#normalized_input_data = normalize_function(input_data)
prediction = model.predict(input_data)
prediction.round()
# Out:
# /home/acer/.local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17.])

# %%
y_pred
# Out:
# array([15.12417853, 22.68105517, 26.90448031, ..., 30.85391257,
#        26.45930977, 22.65081024])

# %%
y_test
# Out:
# 26638    17
# 22220    23
# 35649    27
# 37533    29
# 32702    27
#          ..
# 12709    30
# 12524    27
# 15421    31
# 44125    25
# 23704    23
# Name: tempC, Length: 9101, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have y_test and y_pred from your weather prediction model
# Replace these with your actual data


# Create a scatter plot
plt.scatter(y_test, y_pred, c='blue', label='Actual vs. Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', label='Prediction')

# Add labels and title
plt.xlabel('Actual Values (y_test)')
plt.ylabel('Predicted Values (y_pred)')
plt.title('Scatter Plot of Actual vs. Predicted Values')

# Add a legend
plt.legend()

# Show the plot
plt.show()
