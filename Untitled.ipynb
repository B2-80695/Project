# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %matplotlib inline

# %%
weather_df = pd.read_csv('pune.csv', parse_dates=['date_time'], index_col='date_time')
weather_df.head(5)
# Out:
#                      maxtempC  mintempC  sunHour  uvIndex  moon_illumination  \
# date_time
# 2017-01-01 01:00:00      31.0      17.0     11.0      6.0               20.0
# 2017-01-01 02:00:00      31.0      17.0     11.0      6.0               20.0
# 2017-01-01 03:00:00      31.0      17.0     11.0      6.0               20.0
# 2017-01-01 04:00:00      31.0      17.0     11.0      6.0               20.0
# 2017-01-01 05:00:00      31.0      17.0      NaN      6.0               20.0
#
#                      moonrise   moonset   sunrise    sunset  DewPointC  ...  \
# date_time                                                               ...
# 2017-01-01 01:00:00  09:15 AM  08:58 PM  07:07 AM  06:09 PM    20714.0  ...
# 2017-01-01 02:00:00  09:15 AM  08:58 PM  07:07 AM  06:09 PM    20715.0  ...
# 2017-01-01 03:00:00  09:15 AM  08:58 PM  07:07 AM  06:09 PM    20716.0  ...
# 2017-01-01 04:00:00  09:15 AM  08:58 PM  07:07 AM  06:09 PM    20717.0  ...
# 2017-01-01 05:00:00  09:15 AM  08:58 PM  07:07 AM  06:09 PM    20718.0  ...
#
#                      WindChillC  WindGustKmph  cloudcover  humidity  precipMM  \
# date_time
# 2017-01-01 01:00:00        18.0           5.0           1        63       0.0
# 2017-01-01 02:00:00        18.0           5.0           0        63       0.0
# 2017-01-01 03:00:00        17.0           6.0           0        64       0.0
# 2017-01-01 04:00:00        19.0           7.0           1        57       0.0
# 2017-01-01 05:00:00        19.0           8.0           1        51       0.0
#
#                      pressure  tempC  visibility  winddirDegree  windspeedKmph
# date_time
# 2017-01-01 01:00:00    1014.0     18          10             82              2
# 2017-01-01 02:00:00    1014.0     18          10             94              3
# 2017-01-01 03:00:00    1014.0     17          10            105              3
# 2017-01-01 04:00:00    1014.0     19          10            110              4
# 2017-01-01 05:00:00    1015.0     19          10            115              5
#
# [5 rows x 22 columns]

# %%
weather_df.columns
# Out:
# Index(['maxtempC', 'mintempC', 'sunHour', 'uvIndex', 'moon_illumination',
#        'moonrise', 'moonset', 'sunrise', 'sunset', 'DewPointC', 'FeelsLikeC',
#        'HeatIndexC', 'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity',
#        'precipMM', 'pressure', 'tempC', 'visibility', 'winddirDegree',
#        'windspeedKmph'],
#       dtype='object')

# %%
weather_df.shape
# Out:
# (45503, 22)

# %%
weather_df.describe()
# Out:
#            maxtempC      mintempC       sunHour       uvIndex  \
# count  44633.000000  45478.000000  45351.000000  45450.000000
# mean      30.831201     21.249307     11.087453      6.266249
# std        4.242974      2.667357      1.002336      0.924189
# min       22.000000     11.000000      8.300000      4.000000
# 25%       28.000000     20.000000     10.500000      6.000000
# 50%       30.000000     22.000000     11.000000      6.000000
# 75%       34.000000     23.000000     11.800000      7.000000
# max       42.000000     28.000000     13.500000      8.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       45502.000000  45500.000000  45503.000000  45503.000000
# mean           46.087557  43464.701736     26.322221     26.491462
# std            31.231273  13136.110646      4.384641      4.242005
# min             0.000000  20714.000000     10.000000     11.000000
# 25%            19.000000  32088.750000     25.000000     25.000000
# 50%            46.000000  43463.500000     26.000000     26.000000
# 75%            73.000000  54841.250000     29.000000     29.000000
# max           100.000000  66216.000000     44.000000     44.000000
#
#          WindChillC  WindGustKmph    cloudcover      humidity      precipMM  \
# count  45478.000000  45494.000000  45503.000000  45503.000000  45487.000000
# mean      25.437706     18.101552     31.633013     56.551348      0.246156
# std        4.562040      8.647081     33.945653     24.535400      0.883922
# min       10.000000      1.000000      0.000000      4.000000      0.000000
# 25%       23.000000     12.000000      2.000000     36.000000      0.000000
# 50%       25.000000     16.000000     13.000000     57.000000      0.000000
# 75%       28.000000     23.000000     66.000000     80.000000      0.100000
# max       42.000000     76.000000    100.000000     98.000000     25.700000
#
#            pressure         tempC    visibility  winddirDegree  windspeedKmph
# count  45501.000000  45503.000000  45503.000000   45503.000000   45503.000000
# mean    1009.847981     25.438543      9.629739     208.436389      10.298332
# std        3.594591      4.562331      1.131830      87.580946       5.138205
# min      997.000000     11.000000      2.000000       0.000000       0.000000
# 25%     1007.000000     23.000000     10.000000     113.000000       6.000000
# 50%     1010.000000     25.000000     10.000000     253.000000       9.000000
# 75%     1013.000000     28.000000     10.000000     273.000000      14.000000
# max     1020.000000     42.000000     10.000000     360.000000      40.000000

# %%
weather_df.isnull().any()
# Out:
# maxtempC              True
# mintempC              True
# sunHour               True
# uvIndex               True
# moon_illumination     True
# moonrise             False
# moonset              False
# sunrise              False
# sunset               False
# DewPointC             True
# FeelsLikeC           False
# HeatIndexC           False
# WindChillC            True
# WindGustKmph          True
# cloudcover           False
# humidity             False
# precipMM              True
# pressure              True
# tempC                False
# visibility           False
# winddirDegree        False
# windspeedKmph        False
# dtype: bool

# %%
weather_df_num=weather_df.loc[:,['maxtempC','mintempC','cloudcover','humidity','tempC', 'sunHour','HeatIndexC', 'precipMM', 'pressure','windspeedKmph']]
weather_df_num.head()
# Out:
#                      maxtempC  mintempC  cloudcover  humidity  tempC  sunHour  \
# date_time
# 2017-01-01 01:00:00      31.0      17.0           1        63     18     11.0
# 2017-01-01 02:00:00      31.0      17.0           0        63     18     11.0
# 2017-01-01 03:00:00      31.0      17.0           0        64     17     11.0
# 2017-01-01 04:00:00      31.0      17.0           1        57     19     11.0
# 2017-01-01 05:00:00      31.0      17.0           1        51     19      NaN
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2017-01-01 01:00:00          18       0.0    1014.0              2
# 2017-01-01 02:00:00          18       0.0    1014.0              3
# 2017-01-01 03:00:00          17       0.0    1014.0              3
# 2017-01-01 04:00:00          19       0.0    1014.0              4
# 2017-01-01 05:00:00          19       0.0    1015.0              5

# %%
weather_df_num.shape
# Out:
# (45503, 10)

# %%
weather_df_num.columns
# Out:
# Index(['maxtempC', 'mintempC', 'cloudcover', 'humidity', 'tempC', 'sunHour',
#        'HeatIndexC', 'precipMM', 'pressure', 'windspeedKmph'],
#       dtype='object')

# %%
weather_df_num.plot(subplots=True, figsize=(25,20))
# Out:
# array([<Axes: xlabel='date_time'>, <Axes: xlabel='date_time'>,
#        <Axes: xlabel='date_time'>, <Axes: xlabel='date_time'>,
#        <Axes: xlabel='date_time'>, <Axes: xlabel='date_time'>,
#        <Axes: xlabel='date_time'>, <Axes: xlabel='date_time'>,
#        <Axes: xlabel='date_time'>, <Axes: xlabel='date_time'>],
#       dtype=object)

# %%
weather_df_num.hist(bins=10,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'maxtempC'}>,
#         <Axes: title={'center': 'mintempC'}>,
#         <Axes: title={'center': 'cloudcover'}>],
#        [<Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'tempC'}>,
#         <Axes: title={'center': 'sunHour'}>],
#        [<Axes: title={'center': 'HeatIndexC'}>,
#         <Axes: title={'center': 'precipMM'}>,
#         <Axes: title={'center': 'pressure'}>],
#        [<Axes: title={'center': 'windspeedKmph'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
filled_df=weather_df_num.fillna(method='pad')

# %%
weather_y=filled_df.pop("tempC")
weather_x=filled_df

# %%
train_X,test_X,train_y,test_y=train_test_split(weather_x,weather_y,test_size=0.2,random_state=4)

# %%
train_X.shape
# Out:
# (36402, 9)

# %%
train_y.shape
# Out:
# (36402,)

# %%
train_y.head()
# Out:
# date_time
# 2018-05-11 23:00:00    27
# 2021-11-16 15:00:00    29
# 2020-11-23 21:00:00    23
# 2019-09-01 16:00:00    24
# 2018-10-30 23:00:00    21
# Name: tempC, dtype: int64

# %%
model=LinearRegression()
model.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
prediction = model.predict(test_X)

# %%
np.mean(np.absolute(prediction-test_y))
# Out:
# 0.7299693850400445

# %%
print('Variance score: %.2f' % model.score(test_X, test_y))
# Out:
# Variance score: 0.96

# %%
for i in range(len(prediction)):
  prediction[i]=round(prediction[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction,'diff':(test_y-prediction)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2019-11-15 03:00:00      20       17.66  2.34
# 2020-03-27 12:00:00      32       31.22  0.78
# 2020-09-18 07:00:00      22       22.57 -0.57
# 2018-10-06 03:00:00      24       23.04  0.96
# 2019-07-18 15:00:00      28       28.15 -0.15
# ...                     ...         ...   ...
# 2018-02-14 05:00:00      19       18.56  0.44
# 2017-03-05 17:00:00      29       28.56  0.44
# 2022-01-23 16:00:00      23       25.49 -2.49
# 2019-09-13 10:00:00      24       23.70  0.30
# 2021-08-18 12:00:00      22       22.64 -0.64
#
# [9101 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
prediction2=regressor.predict(test_X)
np.mean(np.absolute(prediction2-test_y))
# Out:
# 0.39449877302860487

# %%
print('Variance score: %.2f' % regressor.score(test_X, test_y))
# Out:
# Variance score: 0.98

# %%
for i in range(len(prediction2)):
  prediction2[i]=round(prediction2[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction2,'diff':(test_y-prediction2)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2019-11-15 03:00:00      20        20.0   0.0
# 2020-03-27 12:00:00      32        32.0   0.0
# 2020-09-18 07:00:00      22        23.0  -1.0
# 2018-10-06 03:00:00      24        24.0   0.0
# 2019-07-18 15:00:00      28        27.0   1.0
# ...                     ...         ...   ...
# 2018-02-14 05:00:00      19        19.0   0.0
# 2017-03-05 17:00:00      29        28.0   1.0
# 2022-01-23 16:00:00      23        25.0  -2.0
# 2019-09-13 10:00:00      24        24.0   0.0
# 2021-08-18 12:00:00      22        22.0   0.0
#
# [9101 rows x 3 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
regr=RandomForestRegressor(max_depth=90,random_state=0,n_estimators=100)
regr.fit(train_X,train_y)
# Out:
# RandomForestRegressor(max_depth=90, random_state=0)

# %%
prediction3=regr.predict(test_X)
np.mean(np.absolute(prediction3-test_y))
# Out:
# 0.34857146912165593

# %%
print('Variance score: %.2f' % regr.score(test_X, test_y))
# Out:
# Variance score: 0.99

# %%
for i in range(len(prediction3)):
  prediction3[i]=round(prediction3[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction3,'diff':(test_y-prediction3)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2019-11-15 03:00:00      20       20.00  0.00
# 2020-03-27 12:00:00      32       31.76  0.24
# 2020-09-18 07:00:00      22       22.68 -0.68
# 2018-10-06 03:00:00      24       23.99  0.01
# 2019-07-18 15:00:00      28       27.45  0.55
# ...                     ...         ...   ...
# 2018-02-14 05:00:00      19       19.00  0.00
# 2017-03-05 17:00:00      29       29.38 -0.38
# 2022-01-23 16:00:00      23       24.60 -1.60
# 2019-09-13 10:00:00      24       23.92  0.08
# 2021-08-18 12:00:00      22       22.42 -0.42
#
# [9101 rows x 3 columns]

# %%
from sklearn.metrics import r2_score

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction ) )
# Out:
# Mean absolute error: 0.73
# Residual sum of squares (MSE): 0.90
# R2-score: 0.96

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction2 - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction2 - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction2 ) )
# Out:
# Mean absolute error: 0.39
# Residual sum of squares (MSE): 0.51
# R2-score: 0.98

# %%
from sklearn.metrics import r2_score

print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction3 - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction3 - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction3 ) )
# Out:
# Mean absolute error: 0.35
# Residual sum of squares (MSE): 0.27
# R2-score: 0.99
